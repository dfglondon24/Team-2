# %%
import pandas as pd

# %%
def read_data(filename: str):
    """
    Function to read in an excel file, and convert it to a Pandas dataframe
    """
    
    print("Note: filename input should not include 'shared_data_read_only/'")
    print("Example: filename = 'AfriKids/InternalData/1. Master Stats 2023.xlsx'")
    
    df = pd.read_excel('shared_data_read_only/Data/' + filename)
    
    return df

# %%
# Example use

# Read in file
df = read_data('AfriKids/InternalData/1. Master Stats 2023.xlsx')

# Print first 5 rows
df.head(5)
# Out:
# Note: filename input should not include 'shared_data_read_only/'
# Example: filename = 'AfriKids/InteralData/1. Master Stats 2023.xlsx'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 4
#       1 # Example use
#       2
#       3 # Read in file
# ----> 4 df = read_data('AfriKids/InternalData/1. Master Stats 2023.xlsx')
#       6 # Print first 5 rows
#       7 df.head(5)
#
# Cell In[4], line 9, in read_data(filename)
#       6 print("Note: filename input should not include 'shared_data_read_only/'")
#       7 print("Example: filename = 'AfriKids/InteralData/1. Master Stats 2023.xlsx'")
# ----> 9 df = pd.read_excel('shared_data_read_only/Data/' + filename)
#      11 return df
#
# ...

# %%
path = 'AfriKids/ExternalReports/Ghana_2021_Census_Reports/Vol_3D_Literacy and Education_district.xlsx'

df = read_data(path)

df
# Out:
# Note: filename input should not include 'shared_data_read_only/'
# Example: filename = 'AfriKids/InteralData/1. Master Stats 2023.xlsx'
#     Table 3D.1a: Population 6 years and older by literacy status, sex, type of locality and district  \
# 0                                      Literacy Status
# 1                                                  NaN
# 2                                   All Locality Types
# 3                                           Both sexes
# 4                                                Total
# ..                                                 ...
# 823                                                NaN
# 824                                             Female
# 825                                              Total
# 826                                       Not literate
# 827                                           Literate
#
#          Unnamed: 1 Unnamed: 2  Unnamed: 3        Unnamed: 4  Unnamed: 5  \
# ...
